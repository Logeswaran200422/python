# %% [markdown]
# <a href="https://colab.research.google.com/github/Logeswaran200422/python/blob/main/csv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('netflix_sample-is.csv')
print(df)
# Out:
#                                     title                    director  \
# 0                               Chocolate                         NaN
# 1     Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                         The Zoya Factor             Abhishek Sharma
# 3                               Atlantics                   Mati Diop
# 4                         Chip and Potato                         NaN
# ...                                   ...                         ...
# 5832          Mad Ron's Prevues from Hell                  Jim Monaco
# 5833                             Splatter                   Joe Dante
# 5834              Just Another Love Story                Ole Bornedal
# 5835                      Dinner for Five                         NaN
# 5836                 To and From New York        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# ...

# %%
print(df.head(10))
# Out:
#                                     title                    director  \
# 0                               Chocolate                         NaN
# 1     Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                         The Zoya Factor             Abhishek Sharma
# 3                               Atlantics                   Mati Diop
# 4                         Chip and Potato                         NaN
# 5                            Crazy people                Moses Inwang
# 6                          I Lost My Body               Jérémy Clapin
# 7  Kalushi: The Story of Solomon Mahlangu                 Mandla Dube
# 8                        La Reina del Sur                         NaN
# 9                    Lagos Real Fake Life              Mike Ezuruonye
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# ...

# %%
df.isnull()
# Out:
#       title  director   cast  country  date_added  release_year  rating  \
# 0     False      True  False    False       False         False   False
# 1     False     False  False     True       False         False   False
# 2     False     False  False    False       False         False   False
# 3     False     False  False    False       False         False   False
# 4     False      True  False    False        True         False   False
# ...     ...       ...    ...      ...         ...           ...     ...
# 5832  False     False  False    False       False         False   False
# 5833  False     False  False    False       False         False   False
# 5834  False     False  False    False       False         False   False
# 5835  False      True   True    False       False         False   False
# 5836  False     False  False    False       False         False   False
#
#       duration  listed_in  description   type  show_id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5837 entries, 0 to 5836
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         5837 non-null   object
#  1   director      3936 non-null   object
#  2   cast          5281 non-null   object
#  3   country       5410 non-null   object
#  4   date_added    5195 non-null   object
#  5   release_year  5837 non-null   int64
#  6   rating        5827 non-null   object
#  7   duration      5837 non-null   object
#  8   listed_in     5837 non-null   object
#  9   description   5837 non-null   object
#  10  type          5837 non-null   object
#  11  show_id       5837 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 547.3+ KB

# %%
df.fillna('unknown',inplace=True)
print(df)
# Out:
#                                     title                    director  \
# 0                               Chocolate                     unknown
# 1     Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2                         The Zoya Factor             Abhishek Sharma
# 3                               Atlantics                   Mati Diop
# 4                         Chip and Potato                     unknown
# ...                                   ...                         ...
# 5832          Mad Ron's Prevues from Hell                  Jim Monaco
# 5833                             Splatter                   Joe Dante
# 5834              Just Another Love Story                Ole Bornedal
# 5835                      Dinner for Five                     unknown
# 5836                 To and From New York        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# ...

# %%
import pandas as pd
df=pd.read_csv('netflix_sample-is.csv')
df['date_added']=pd.to_datetime(df['date_added'])
print(df['date_added'])
# Out:
# 0      2019-11-30
# 1      2019-11-30
# 2      2019-11-30
# 3      2019-11-29
# 4             NaT
#           ...
# 5832   2010-11-01
# 5833   2009-11-18
# 5834   2009-05-05
# 5835   2008-02-04
# 5836   2008-01-01
# Name: date_added, Length: 5837, dtype: datetime64[ns]

# %%
df['year']=df['date_added'].dt.year
df['month']=df['date_added'].dt.month
display(df[['date_added','year','month']])
# Out:
#      date_added    year  month
# 0    2019-11-30  2019.0   11.0
# 1    2019-11-30  2019.0   11.0
# 2    2019-11-30  2019.0   11.0
# 3    2019-11-29  2019.0   11.0
# 4           NaT     NaN    NaN
# ...         ...     ...    ...
# 5832 2010-11-01  2010.0   11.0
# 5833 2009-11-18  2009.0   11.0
# 5834 2009-05-05  2009.0    5.0
# 5835 2008-02-04  2008.0    2.0
# 5836 2008-01-01  2008.0    1.0
#
# [5837 rows x 3 columns]

# %%
import pandas as pd
df=pd.read_csv('netflix_sample-is.csv')
df['value']=df['duration'].str.extract(r'(\d+\.?\d*)')
df['unit']=df['duration'].str.extract(r'([a-zA-Z]+)')
display(df[['duration','value','unit']])
# Out:
#        duration value     unit
# 0      1 Season     1   Season
# 1        67 min    67      min
# 2       135 min   135      min
# 3       106 min   106      min
# 4     2 Seasons     2  Seasons
# ...         ...   ...      ...
# 5832     84 min    84      min
# 5833     29 min    29      min
# 5834    104 min   104      min
# 5835   1 Season     1   Season
# 5836     81 min    81      min
#
# [5837 rows x 3 columns]

# %%
df['type'].value_counts()
# Out:
# type
# Movie      3939
# TV Show    1898
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(5)
# Out:
# country
# United States     1907
# India              697
# United Kingdom     336
# Japan              168
# Canada             139
# Name: count, dtype: int64

# %%
df['date_added']=pd.to_datetime(df['date_added'], errors='coerce')
df['year']=df['date_added'].dt.year
df['year'].value_counts().sort_index()
# Out:
# year
# 2008.0       2
# 2009.0       2
# 2010.0       1
# 2011.0      13
# 2012.0       7
# 2013.0       9
# 2014.0      19
# 2015.0      74
# 2016.0     412
# 2017.0    1184
# 2018.0    1629
# 2019.0    1843
# Name: count, dtype: int64

# %%
df['rating'].unique()
# Out:
# array(['TV-14', 'TV-G', 'TV-Y', 'TV-MA', 'TV-PG', 'R', 'TV-Y7', 'PG', 'G',
#        'PG-13', 'TV-Y7-FV', 'NR', 'UR', 'NC-17', nan], dtype=object)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('netflix_sample-is.csv')
type_counts=df['type'].value_counts()
sns.barplot(x=type_counts.index,y=type_counts.values)
plt.title('count of movie shows')
plt.xlabel('Movies')
plt.ylabel('TV Shows')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df['date_added'].dt.year
year_counts = df['year_added'].value_counts().sort_index()
sns.lineplot(x=year_counts.index,y=year_counts.values,marker='o')
plt.title('titles added each year')
plt.xlabel('year')
plt.ylabel('titles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
